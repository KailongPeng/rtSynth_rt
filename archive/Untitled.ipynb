# %%
# sbatch projects/rtSynth_rt/expScripts/recognition/ses1_LOO_Greedy_and_trainTest.sh sub005.ses1.toml 4 tmp__folder_2021-06-30-02-29-57_1625034597.718328/

# %%
# coding=UTF-8
import os
import sys
sys.path.append('/gpfs/milgram/project/turk-browne/projects/rt-cloud/')
sys.path.append('/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt')
sys.path.append('/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/expScripts/recognition/')
import argparse
import numpy as np
import nibabel as nib
import scipy.io as sio
import subprocess
from scipy.stats import zscore
from nibabel.nicom import dicomreaders
import pydicom as dicom  # type: ignore
import time
from glob import glob
import shutil
from nilearn.image import new_img_like
import joblib
import rtCommon.utils as utils
from rtCommon.utils import loadConfigFile
import pickle5 as pickle
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
# from rtCommon.fileClient import FileInterface
# import rtCommon.projectUtils as projUtils
# from rtCommon.imageHandling import readRetryDicomFromFileInterface, getDicomFileName, convertDicomImgToNifti


argParser = argparse.ArgumentParser()
argParser.add_argument('--config', '-c', default='sub005.ses1.toml', type=str, help='experiment file (.json or .toml)')
argParser.add_argument('--skipPre', '-s', default=False, action='store_true', help='skip preprocess or not')
argParser.add_argument('--skipGreedy', '-g', default=0, type=int, help='skip greedy or not')
argParser.add_argument('--forceGreedy', default=False, action='store_true', help='whether to force Greedy search in current session')
argParser.add_argument('--testRun', '-t', default=None, type=int, help='testRun, can be [None,1,2,3,4,5,6,7,8]')
argParser.add_argument('--scan_asTemplate', '-a', default=1, type=int, help="which scan's middle dicom as Template?")
argParser.add_argument('--preprocessOnly', default=False, action='store_true', help='whether to only do preprocess and skip everything else')
argParser.add_argument('--LeaveOutRun', '-l', default=None, type=int, help='testRun, can be [None,1,2,3,4,5,6,7,8]')
argParser.add_argument('--jobID', default='' , type=str, help='jobID')
argParser.add_argument('--tmp_folder', default='tmp__folder_2021-06-30-02-29-57_1625034597.718328/', type=str, help='tmp_folder')

args = argParser.parse_args("")
from cfg_loading import mkdir,cfg_loading
# config="sub001.ses2.toml"
cfg = cfg_loading(args.config)
cfg.jobID=args.jobID
cfg
# Out:
# conda env=/gpfs/milgram/project/turk-browne/users/kp578/CONDA/rtcloud
# {'title': 'rtSynth_rt',
#  'session': 1,
#  'subjectDay': 1,
#  'subjectIDforxnat': 'rtSynth_sub005_ses1',
#  'preDay_YYYYMMDD': '0',
#  'YYYYMMDD': '20210629',
#  'subjectName': 'sub005',
#  'LASTNAME': 'rtSynth_sub005',
#  'realtimeFolder_subjectName': 'rtSynth_sub005',
#  'studyDescription': 'rtSynth_rt',
#  'num_total_TRs': 174,
#  'TrialNumber': 12,
#  'runNum': [1],
#  'scanNum': [1],
#  'plotTitle': 'Realtime Plot',
#  'plotXLabel': 'Sample #',
#  'plotYLabel': 'B prob',
#  'plotXRangeLow': 0,
#  'plotXRangeHigh': 176,
#  'plotYRangeLow': 0,
#  'plotYRangeHigh': 20,
#  'plotAutoRangeX': False,
#  'plotAutoRangeY': True,
#  'minExpectedDicomSize': 460000,
#  'trying': False,
#  'projectDir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/',
#  'orderFolder': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/expScripts/recognition/orders/',
#  'subjects_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/',
#  'dicom_folder': '/gpfs/milgram/project/realtime/DICOM/',
#  'recognition_expScripts_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/expScripts/recognition/',
#  'feedback_expScripts_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/expScripts/feedback/',
#  'preDay_dicom_dir': '/gpfs/milgram/project/realtime/DICOM/0.rtSynth_sub005.rtSynth_sub005/',
#  'dicom_dir': '/gpfs/milgram/project/realtime/DICOM/20210629.rtSynth_sub005.rtSynth_sub005_ses1//',
#  'TR': 2,
#  'tmp_folder': '/tmp/',
#  'dicomDir': '/gpfs/milgram/project/realtime/DICOM/20210629.rtSynth_sub005.rtSynth_sub005_ses1//',
#  'recognition_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition/',
#  'feedback_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/feedback/',
#  'usingModel_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses0/recognition/clf/',
#  'trainingModel_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition/clf/',
#  'chosenMask': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition/chosenMask.npy',
#  'chosenMask_training': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition/chosenMask.npy',
#  'chosenMask_using': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses0/recognition/chosenMask.npy',
#  'templateFunctionalVolume': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition/templateFunctionalVolume.nii',
#  'templateFunctionalVolume_converted': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition//templateFunctionalVolume_converted.nii',
#  'dicomNamePattern': '001_{SCAN:06d}_{TR:06d}.dcm',
#  'mask_dir': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/recognition/mask/',
#  'GMINFUNC': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/ses1/anat/gm_func.nii.gz',
#  'adaptiveThreshold': '/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/subjects/sub005/adaptiveThreshold.csv',
#  'twoWayClfDict': {'AB': ['bedtable_bedchair', '\nbedtable_tablebench'],
#   'AC': ['bedchair_bedtable', '\nbedchair_chairbench'],
#   'AD': ['bedchair_bedbench', '\nbedchair_bedtable'],
#   'BC': ['bedchair_chairtable', '\nbedtable_bedbench'],
#   'BD': ['bedchair_chairbench', '\nbedchair_chairtable'],
#   'CD': ['bedtable_tablebench', '\nbedtable_tablechair']},
#  'jobID': ''}

# %%
from recognition_dataAnalysisFunctions import behaviorDataLoading,normalize,append_file

def wait(waitfor, delay=1):
    while not os.path.exists(waitfor):
        time.sleep(delay)
        print('waiting for {}'.format(waitfor))

def greedyMask(cfg,N=78,LeaveOutRun=1,recordingTxt = "", tmp_folder=''): # N used to be 31, 25 
    import os
    import numpy as np
    import nibabel as nib
    import sys
    sys.path.append('/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/')
    import time
    import pandas as pd
    from sklearn.linear_model import LogisticRegression
    import itertools
    # from tqdm import tqdm
    import pickle5 as pickle
    import subprocess
    from subprocess import call
    def save_obj(obj, name):
        with open(name + '.pkl', 'wb') as f:
            pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

    def load_obj(name):
        with open(name + '.pkl', 'rb') as f:
            return pickle.load(f)

    # What subject are you running
    '''
    Takes args (in order):
        subject (e.g. sub001)
        dataSource (e.g. realtime)
        roiloc (wang2014 or schaefer2018)
        N (the number of parcels or ROIs to start with)
    '''


    from cfg_loading import mkdir,cfg_loading
    # config="sub001.ses1.toml"
    # cfg = cfg_loading(config)

    subject,dataSource,roiloc,N=cfg.subjectName,"realtime","schaefer2018",N
    # subject,dataSource,roiloc,N=sys.argv[1],sys.argv[2],sys.argv[3],int(sys.argv[4])

    print("Running subject {}, with {} as a data source, {}, starting with {} ROIs".format(subject, dataSource, roiloc, N))

    # funcdata = cfg.recognition_dir + "brain_run{run}.npy"
    # metadata = cfg.recognition_dir + "behav_run{run}.csv"

    topN = load_obj(f"{cfg.recognition_expScripts_dir}top{N}ROIs")
    print(f"len(topN)={len(topN)}")
    print(f"GMschaefer_ topN loaded from neurosketch={topN}")

    def Wait(waitfor, delay=1):
        while not os.path.exists(waitfor):
            time.sleep(delay)
            print('waiting for {}'.format(waitfor))

    imcodeDict={"A": "bed", "B": "Chair", "C": "table", "D": "bench"}
    if recordingTxt=='':
        recordingTxt=f"{cfg.projectDir}{tmp_folder}/recording.txt"
    def getMask(topN, cfg):
        for pn, parc in enumerate(topN):
            _mask = nib.load(f"{cfg.subjects_dir}{cfg.subjectName}/ses1/recognition/mask/GMschaefer_{parc}")
            # schaefer_56.nii.gz
            aff = _mask.affine
            _mask = _mask.get_data()
            _mask = _mask.astype(int)
            # say some things about the mask.
            mask = _mask if pn == 0 else mask + _mask
            mask[mask>0] = 1
        return mask

    mask=getMask(topN, cfg)

    print('mask dimensions: {}'. format(mask.shape))
    print('number of voxels in mask: {}'.format(np.sum(mask)))


    runRecording = pd.read_csv(f"{cfg.recognition_dir}../runRecording.csv")
    actualRuns = list(runRecording['run'].iloc[list(np.where(1==1*(runRecording['type']=='recognition'))[0])]) # can be [1,2,3,4,5,6,7,8] or [1,2,4,5]
    if len(actualRuns) < 8:
        runRecording_preDay = pd.read_csv(f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session-1}/recognition/../runRecording.csv")
        actualRuns_preDay = list(runRecording_preDay['run'].iloc[list(np.where(1==1*(runRecording_preDay['type']=='recognition'))[0])])[-(8-len(actualRuns)):] # might be [5,6,7,8]
    else: 
        actualRuns_preDay = []

    # assert len(actualRuns_preDay)+len(actualRuns)==8 
    if len(actualRuns_preDay)+len(actualRuns)<8:
        runRecording_prepreDay = pd.read_csv(f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session-2}/recognition/../runRecording.csv")
        actualRuns_prepreDay = list(runRecording_prepreDay['run'].iloc[list(np.where(1==1*(runRecording_prepreDay['type']=='recognition'))[0])])[-(8-len(actualRuns)-len(actualRuns_preDay)):] # might be [5,6,7,8]
    else:
        actualRuns_prepreDay = []

    objects = ['bed', 'bench', 'chair', 'table']

    brain_data=[]
    behav_data=[]
    actualRuns.remove(actualRuns[LeaveOutRun-1])
    print(f"actualRuns={actualRuns} after removal")

    for ii,run in enumerate(actualRuns): # load behavior and brain data for current session
        t = np.load(f"{cfg.recognition_dir}brain_run{run}.npy")
        t = normalize(t)
        brain_data.append(t)

        t = pd.read_csv(f"{cfg.recognition_dir}behav_run{run}.csv")
        t=list(t['Item'])
        behav_data.append(t)
    
    if tmp_folder=='' or tmp_folder=='_':
        tmp_folder = f"tmp__folder_{time.strftime('%Y-%m-%d-%H-%M-%S', time.localtime(time.time()))}_{time.time()}" 
    print(f"tmp_folder={tmp_folder}")
    mkdir(f"{cfg.projectDir}{tmp_folder}")
    save_obj([brain_data,behav_data],f"{cfg.projectDir}{tmp_folder}/{subject}_{dataSource}_{roiloc}_{N}") #{len(topN)}_{i}

    def wait(tmpFile):
        while not os.path.exists(tmpFile+'_result.npy'):
            time.sleep(5)
            print(f"waiting for {tmpFile}_result.npy\n")
        time.sleep(2)
        return np.load(tmpFile+'_result.npy',allow_pickle=True)

    def numOfRunningJobs():
        # subprocess.Popen(['squeue -u kp578 | wc -l > squeue.txt'],shell=True) # sl_result = Class(_runs, bcvar)
        randomID=str(time.time())
        # print(f"squeue -u kp578 | wc -l > squeue/{randomID}.txt")
        call(f'squeue -u kp578 | wc -l > {cfg.projectDir}squeue/{randomID}.txt',shell=True)
        numberOfJobsRunning = int(open(f"{cfg.projectDir}squeue/{randomID}.txt", "r").read())
        print(f"numberOfJobsRunning={numberOfJobsRunning}")
        return numberOfJobsRunning

    def Class(brain_data,behav_data):
        # metas = bcvar[0]
        # data4d = data[0]
        print([t.shape for t in brain_data])

        accs = []
        for run in range(len(brain_data)):
            testX = brain_data[run]
            testY = behav_data[run]

            trainX=np.zeros((1,1))
            for i in range(len(brain_data)):
                if i !=run:
                    trainX=brain_data[i] if trainX.shape==(1,1) else np.concatenate((trainX,brain_data[i]),axis=0)

            trainY = []
            for i in range(len(brain_data)):
                if i != run:
                    trainY.extend(behav_data[i])
            clf = LogisticRegression(penalty='l2',C=1, solver='lbfgs', max_iter=1000, 
                                    multi_class='multinomial').fit(trainX, trainY)
                    
            # Monitor progress by printing accuracy (only useful if you're running a test set)
            acc = clf.score(testX, testY)
            accs.append(acc)
        
        return np.mean(accs)

    if not os.path.exists(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}.pkl"):
        brain_data = [t[:,mask==1] for t in brain_data]
        # _runs = [runs[:,mask==1]]
        print("Runs shape", [t.shape for t in brain_data])
        slstart = time.time()
        sl_result = Class(brain_data, behav_data)
        print(f"passed {time.time()-slstart}s for training")
        save_obj({"subject":subject,
        "startFromN":N,
        "currNumberOfROI":len(topN),
        "bestAcc":sl_result, # this is the sl_result for the topN, not the bestAcc, bestAcc is for the purpose of keeping consistent with others
        "bestROIs":topN},# this is the topN, not the bestROIs, bestROIs is for the purpose of keeping consistent with others
        f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}"
        )

    if os.path.exists(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{1}.pkl"):
        print(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_1.pkl exists")


        # when every mask has run, find the best mask and save as the chosenMask
        roiloc="schaefer2018"
        dataSource="realtime"
        subjects=[cfg.subjectName]
        N=N
        GreedyBestAcc=np.zeros((len(subjects),N+1))
        GreedyBestAcc[GreedyBestAcc==0]=None
        for ii,subject in enumerate(subjects):
            for len_topN_1 in range(N-1,0,-1):
                try:
                    # print(f"./{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                    di = load_obj(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                    GreedyBestAcc[ii,len_topN_1-1] = di['bestAcc']
                except:
                    pass
        GreedyBestAcc=GreedyBestAcc.T

        # import matplotlib.pyplot as plt
        # plt.imshow(GreedyBestAcc)
        # _=plt.figure()
        # for i in range(GreedyBestAcc.shape[0]):
        #     plt.scatter([i]*GreedyBestAcc.shape[1],GreedyBestAcc[i],c='g',s=2)
        # plt.plot(np.arange(GreedyBestAcc.shape[0]),np.nanmean(GreedyBestAcc,axis=1))

        performance_mean = np.nanmean(GreedyBestAcc,axis=1)
        bestID=np.where(performance_mean==max(performance_mean))[0][0]
        di = load_obj(f"{cfg.projectDir}/{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{bestID+1}")
        print(f"bestID={bestID}; best Acc = {di['bestAcc']}")
        print(f"bestROIs={di['bestROIs']}")
        
        append_file(recordingTxt,f"bestID={bestID}; best Acc = {di['bestAcc']}")
        append_file(recordingTxt,f"bestROIs={di['bestROIs']}")

        mask = getMask(di['bestROIs'],cfg)
        np.save(f"{cfg.recognition_dir}chosenMask_leave_{LeaveOutRun}_out.npy",mask)
        
        
        return recordingTxt
        # raise Exception('runned or running')

    # N-1
    def next(topN):
        print(f"len(topN)={len(topN)}")
        print(f"topN={topN}")

        if len(topN)==1:
            return None
        else:
            allpairs = itertools.combinations(topN,len(topN)-1)
            topNs=[]
            sl_results=[]
            tmpFiles=[]
            while os.path.exists(f"{cfg.projectDir}{tmp_folder}/holdon.npy"):
                time.sleep(10)
                print(f"sleep for 10s ; waiting for {cfg.projectDir}{tmp_folder}/holdon.npy to be deleted")
            np.save(f"{cfg.projectDir}{tmp_folder}/holdon",1)

            # 对于每一个round，提交一个job array，然后等待这个job array完成之后再进行下一轮
            # 具体的方法是首先保存需要的input，也就是这一轮需要用到的tmpFile，然后再将tmpFile除了之外的字符串输入
            skip_flag=0
            for i,_topN in enumerate(allpairs):
                tmpFile=f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}_{i}"
                print(f"tmpFile={tmpFile}")
                topNs.append(_topN)
                tmpFiles.append(tmpFile)

                if not os.path.exists(tmpFile+'_result.npy'):
                    # prepare brain data(runs) mask and behavior data(bcvar) 
                    save_obj([_topN,subject,dataSource,roiloc,N], tmpFile)
                else:
                    print(tmpFile+'_result.npy exists!')
                    skip_flag+=1

            if skip_flag!=(i+1): # 如果有一个不存在，就需要跑一跑
                command=f'sbatch --array=1-{i+1} {cfg.recognition_expScripts_dir}class_LOO.sh {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}_'
                print(command)
                proc = subprocess.Popen([command], shell=True) # sl_result = Class(_runs, bcvar) 
            else:
                command=f'sbatch --array=1-{i+1} {cfg.recognition_expScripts_dir}class_LOO.sh {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}_'
                print(f"skip {command}")
            try:
                os.remove(f"{cfg.projectDir}{tmp_folder}/holdon.npy")
            except:
                pass
            # wait for everything to be finished and make a summary to find the best performed megaROI
            sl_results=[]
            for tmpFile in tmpFiles:
                sl_result=wait(tmpFile)
                sl_results.append(sl_result)
            print(f"sl_results={sl_results}")
            print(f"max(sl_results)=={max(sl_results)}")
            maxID=np.where(sl_results==max(sl_results))[0][0]
            save_obj({"subject":subject,
            "startFromN":N,
            "currNumberOfROI":len(topN)-1,
            "bestAcc":max(sl_results),
            "bestROIs":topNs[maxID]},
            f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}"
            )
            print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
            tmpFiles=next(topNs[maxID])
            return 0
    tmpFiles=next(topN)



    # when every mask has run, find the best mask and save as the chosenMask
    roiloc="schaefer2018"
    dataSource="realtime"
    subjects=[cfg.subjectName]
    N=N
    GreedyBestAcc=np.zeros((len(subjects),N+1))
    GreedyBestAcc[GreedyBestAcc==0]=None
    for ii,subject in enumerate(subjects):
        for len_topN_1 in range(N-1,0,-1):
            try:
                # print(f"./{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                di = load_obj(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                GreedyBestAcc[ii,len_topN_1-1] = di['bestAcc']
            except:
                pass
    GreedyBestAcc=GreedyBestAcc.T

    # import matplotlib.pyplot as plt
    # plt.imshow(GreedyBestAcc)
    # _=plt.figure()
    # for i in range(GreedyBestAcc.shape[0]):
    #     plt.scatter([i]*GreedyBestAcc.shape[1],GreedyBestAcc[i],c='g',s=2)
    # plt.plot(np.arange(GreedyBestAcc.shape[0]),np.nanmean(GreedyBestAcc,axis=1))

    performance_mean = np.nanmean(GreedyBestAcc,axis=1)
    bestID=np.where(performance_mean==max(performance_mean))[0][0]
    di = load_obj(f"{cfg.projectDir}/{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{bestID+1}")
    print(f"bestID={bestID}; best Acc = {di['bestAcc']}")
    print(f"bestROIs={di['bestROIs']}")
    
    append_file(recordingTxt,f"bestID={bestID}; best Acc = {di['bestAcc']}")
    append_file(recordingTxt,f"bestROIs={di['bestROIs']}")

    mask = getMask(di['bestROIs'],cfg)
    np.save(f"{cfg.recognition_dir}chosenMask_leave_{LeaveOutRun}_out.npy",mask)
    
    
    
    return recordingTxt

def minimalClass(cfg,LeaveOutRun=1,recordingTxt=""):
    '''
    purpose: 
        train offline models

    steps:
        load preprocessed and aligned behavior and brain data 
        select data with the wanted pattern like AB AC AD BC BD CD 
        train correspondng classifier and save the classifier performance and the classifiers themselves.
    '''

    import os
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import sklearn
    import joblib
    import nibabel as nib
    import itertools
    from sklearn.linear_model import LogisticRegression

    def other(target):
        other_objs = [i for i in ['bed', 'bench', 'chair', 'table'] if i not in target]
        return other_objs

    def red_vox(n_vox, prop=0.1):
        return int(np.ceil(n_vox * prop))

    if 'milgram' in os.getcwd():
        main_dir='/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/'
    else:
        main_dir='/Users/kailong/Desktop/rtEnv/rt-cloud/projects/rtSynth_rt/'

    working_dir=main_dir
    os.chdir(working_dir)

    '''
    if you read runRecording for current session and found that there are only 4 runs in the current session, 
    you read the runRecording for previous session and fetch the last 4 recognition runs from previous session
    '''
    runRecording = pd.read_csv(f"{cfg.recognition_dir}../runRecording.csv")
    actualRuns = list(runRecording['run'].iloc[list(np.where(1==1*(runRecording['type']=='recognition'))[0])]) # can be [1,2,3,4,5,6,7,8] or [1,2,4,5]
    # if len(actualRuns) < 8:
    #     runRecording_preDay = pd.read_csv(f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session-1}/recognition/../runRecording.csv")
    #     actualRuns_preDay = list(runRecording_preDay['run'].iloc[list(np.where(1==1*(runRecording_preDay['type']=='recognition'))[0])])[-(8-len(actualRuns)):] # might be [5,6,7,8]
    # else: 
    #     actualRuns_preDay = []

    # # assert len(actualRuns_preDay)+len(actualRuns)==8 
    # if len(actualRuns_preDay)+len(actualRuns)<8:
    #     runRecording_prepreDay = pd.read_csv(f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session-2}/recognition/../runRecording.csv")
    #     actualRuns_prepreDay = list(runRecording_prepreDay['run'].iloc[list(np.where(1==1*(runRecording_prepreDay['type']=='recognition'))[0])])[-(8-len(actualRuns)-len(actualRuns_preDay)):] # might be [5,6,7,8]
    # else:
    #     actualRuns_prepreDay = []

    objects = ['bed', 'bench', 'chair', 'table']

    new_run_indexs=[]
    new_run_index=1 #使用新的run 的index，以便于后面的testRun selection的时候不会重复。正常的话 new_run_index 应该是1，2，3，4，5，6，7，8
    for ii,run in enumerate(actualRuns): # load behavior and brain data for current session
        t = np.load(f"{cfg.recognition_dir}brain_run{run}.npy")
        mask = np.load(f"{cfg.recognition_dir}chosenMask_leave_{LeaveOutRun}_out.npy")
        print(f"loading {cfg.recognition_dir}chosenMask_leave_{LeaveOutRun}_out.npy")
        
        t = t[:,mask==1]
        t = normalize(t)
        brain_data=t if ii==0 else np.concatenate((brain_data,t), axis=0)

        t = pd.read_csv(f"{cfg.recognition_dir}behav_run{run}.csv")
        t['run_num'] = new_run_index
        new_run_indexs.append(new_run_index)
        new_run_index+=1
        behav_data=t if ii==0 else pd.concat([behav_data,t])

    FEAT=brain_data.reshape(brain_data.shape[0],-1)

    FEAT=brain_data
    print(f"FEAT.shape={FEAT.shape}")
    assert len(FEAT.shape)==2
    # FEAT_mean=np.mean(FEAT,axis=1)
    # FEAT=(FEAT.T-FEAT_mean).T
    # FEAT_mean=np.mean(FEAT,axis=0)
    # FEAT=FEAT-FEAT_mean
    # FEAT = normalize(FEAT)

    META=behav_data

    # convert item colume to label colume
    imcodeDict={
    'A': 'bed',
    'B': 'chair',
    'C': 'table',
    'D': 'bench'}
    label=[]
    for curr_trial in range(META.shape[0]):
        label.append(imcodeDict[META['Item'].iloc[curr_trial]])
    META['label']=label # merge the label column with the data dataframe

    accTable = pd.DataFrame()

    # Which run to use as test data (leave as None to not have test data)
    # testRun = 0 # when testing: testRun = 2 ; META['run_num'].iloc[:5]=2
    def train4wayClf(META, FEAT, accTable):
        runList = np.unique(list(META['run_num']))
        print(f"runList={runList}")
        accList={}
        for testRun in runList:
            trainIX = META['run_num']!=int(testRun)
            testIX = META['run_num']==int(testRun)

            # pull training and test data
            trainX = FEAT[trainIX]
            testX = FEAT[testIX]
            trainY = META.iloc[np.asarray(trainIX)].label
            testY = META.iloc[np.asarray(testIX)].label

            # Train your classifier
            clf = LogisticRegression(penalty='l2',C=1, solver='lbfgs', max_iter=1000, 
                                        multi_class='multinomial').fit(trainX, trainY)
            
            # model_folder = cfg.trainingModel_dir
            # Save it for later use
            # joblib.dump(clf, model_folder +'/{}.joblib'.format(naming))
            
            # Monitor progress by printing accuracy (only useful if you're running a test set)
            acc = clf.score(testX, testY)
            print("acc=", acc)
            accList[testRun] = acc

            Fourway_acc=acc
            accTable = accTable.append({
                'testRun':testRun,
                'Fourway_acc':Fourway_acc},
                ignore_index=True)

        print(f"new trained full rotation 4 way accuracy mean={np.mean(list(accList.values()))}")
        if recordingTxt!='': #if tmp_folder is not None but some string, save the sentence.  
            append_file(f"{recordingTxt}",f"new trained full rotation 4 way accuracy mean={np.mean(list(accList.values()))}")
        
        return accList, accTable
    accList, accTable = train4wayClf(META, FEAT, accTable)
    
    # 获得full rotation的2way clf的accuracy 平均值 中文
    accs_rotation=[]
    print(f"new_run_indexs={new_run_indexs}")

    # for testRun in new_run_indexs:
    testRun=LeaveOutRun
    allpairs = itertools.combinations(objects,2)
    accs={}
    # Iterate over all the possible target pairs of objects
    for pair in allpairs:
        # Find the control (remaining) objects for this pair
        altpair = other(pair)
        
        # pull sorted indices for each of the critical objects, in order of importance (low to high)
        # inds = get_inds(FEAT, META, pair, testRun=testRun)
        
        # Find the number of voxels that will be left given your inclusion parameter above
        # nvox = red_vox(FEAT.shape[1], include)
        
        for obj in pair:
            # foil = [i for i in pair if i != obj][0]
            for altobj in altpair:
                # establish a naming convention where it is $TARGET_$CLASSIFICATION
                # Target is the NF pair (e.g. bed/bench)
                # Classificationis is btw one of the targets, and a control (e.g. bed/chair, or bed/table, NOT bed/bench)
                naming = '{}{}_{}{}'.format(pair[0], pair[1], obj, altobj)

                if testRun:
                    trainIX = ((META['label']==obj) | (META['label']==altobj)) & (META['run_num']!=int(testRun))
                    testIX = ((META['label']==obj) | (META['label']==altobj)) & (META['run_num']==int(testRun))
                else:
                    trainIX = ((META['label']==obj) | (META['label']==altobj))
                    testIX = ((META['label']==obj) | (META['label']==altobj))

                # pull training and test data
                trainX = FEAT[trainIX]
                testX = FEAT[testIX]
                trainY = META.iloc[np.asarray(trainIX)].label
                testY = META.iloc[np.asarray(testIX)].label

                assert len(np.unique(trainY))==2

                # Train your classifier
                clf = LogisticRegression(penalty='l2',C=1, solver='lbfgs', max_iter=1000, 
                                            multi_class='multinomial').fit(trainX, trainY)
                
                model_folder = cfg.trainingModel_dir
                # Save it for later use
                # joblib.dump(clf, model_folder +'/{}.joblib'.format(naming))
                
                # Monitor progress by printing accuracy (only useful if you're running a test set)
                acc = clf.score(testX, testY)
                print(naming, acc)
                accs[naming]=acc

    for TwoWay_clf in ["AB","CD","AC","AD","BC","BD"]:
        
        accTable.loc[LeaveOutRun-1,TwoWay_clf+'_acc']=accs[cfg.twoWayClfDict[TwoWay_clf][0]]
        print(f"accTable={accTable}")

    print(f"accs={accs}")
    print(f"LeaveOutRun = {LeaveOutRun} : average 2 way clf accuracy={np.mean(list(accs.values()))}")
    # accs_rotation.append(np.mean(list(accs.values())))
    # print(f"mean of 2 way clf acc full rotation = {np.mean(accs_rotation)}")
    if recordingTxt: #if tmp_folder is not None but some string, save the sentence.
        append_file(f"{recordingTxt}",f"accs={accs}")
        append_file(f"{recordingTxt}",f"LeaveOutRun = {LeaveOutRun} : average 2 way clf accuracy={np.mean(list(accs.values()))}")
    
    accTable.to_csv(f"{cfg.projectDir}/../../logs/accTable_{cfg.jobID}.csv") 
    cfg.accTable=accTable
    return accs,cfg

# %%
# recordingTxt=f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session}/recognition/recording.txt" # None
forceGreedy="forceGreedy"
recordingTxt=''
if args.tmp_folder=="_":
    tmp_folder=''
else:
    tmp_folder=args.tmp_folder

# for LeaveOutRun in range(1,9):
LeaveOutRun=4
print(f"LeaveOutRun={LeaveOutRun}")
# Out:
# LeaveOutRun=4

# %%
def greedyMask(cfg,N=78,LeaveOutRun=1,recordingTxt = "", tmp_folder=''): # N used to be 31, 25 
    import os
    import numpy as np
    import nibabel as nib
    import sys
    sys.path.append('/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/')
    import time
    import pandas as pd
    from sklearn.linear_model import LogisticRegression
    import itertools
    # from tqdm import tqdm
    import pickle5 as pickle
    import subprocess
    from subprocess import call
    def save_obj(obj, name):
        with open(name + '.pkl', 'wb') as f:
            pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

    def load_obj(name):
        with open(name + '.pkl', 'rb') as f:
            return pickle.load(f)

    # What subject are you running
    '''
    Takes args (in order):
        subject (e.g. sub001)
        dataSource (e.g. realtime)
        roiloc (wang2014 or schaefer2018)
        N (the number of parcels or ROIs to start with)
    '''


    from cfg_loading import mkdir,cfg_loading
    # config="sub001.ses1.toml"
    # cfg = cfg_loading(config)

    subject,dataSource,roiloc,N=cfg.subjectName,"realtime","schaefer2018",N
    # subject,dataSource,roiloc,N=sys.argv[1],sys.argv[2],sys.argv[3],int(sys.argv[4])

    print("Running subject {}, with {} as a data source, {}, starting with {} ROIs".format(subject, dataSource, roiloc, N))

    # funcdata = cfg.recognition_dir + "brain_run{run}.npy"
    # metadata = cfg.recognition_dir + "behav_run{run}.csv"

    topN = load_obj(f"{cfg.recognition_expScripts_dir}top{N}ROIs")
    print(f"len(topN)={len(topN)}")
    print(f"GMschaefer_ topN loaded from neurosketch={topN}")

    def Wait(waitfor, delay=1):
        while not os.path.exists(waitfor):
            time.sleep(delay)
            print('waiting for {}'.format(waitfor))

    imcodeDict={"A": "bed", "B": "Chair", "C": "table", "D": "bench"}
    if recordingTxt=='':
        recordingTxt=f"{cfg.projectDir}{tmp_folder}/recording.txt"
    def getMask(topN, cfg):
        for pn, parc in enumerate(topN):
            _mask = nib.load(f"{cfg.subjects_dir}{cfg.subjectName}/ses1/recognition/mask/GMschaefer_{parc}")
            # schaefer_56.nii.gz
            aff = _mask.affine
            _mask = _mask.get_data()
            _mask = _mask.astype(int)
            # say some things about the mask.
            mask = _mask if pn == 0 else mask + _mask
            mask[mask>0] = 1
        return mask

    mask=getMask(topN, cfg)

    print('mask dimensions: {}'. format(mask.shape))
    print('number of voxels in mask: {}'.format(np.sum(mask)))


    runRecording = pd.read_csv(f"{cfg.recognition_dir}../runRecording.csv")
    actualRuns = list(runRecording['run'].iloc[list(np.where(1==1*(runRecording['type']=='recognition'))[0])]) # can be [1,2,3,4,5,6,7,8] or [1,2,4,5]
    if len(actualRuns) < 8:
        runRecording_preDay = pd.read_csv(f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session-1}/recognition/../runRecording.csv")
        actualRuns_preDay = list(runRecording_preDay['run'].iloc[list(np.where(1==1*(runRecording_preDay['type']=='recognition'))[0])])[-(8-len(actualRuns)):] # might be [5,6,7,8]
    else: 
        actualRuns_preDay = []

    # assert len(actualRuns_preDay)+len(actualRuns)==8 
    if len(actualRuns_preDay)+len(actualRuns)<8:
        runRecording_prepreDay = pd.read_csv(f"{cfg.subjects_dir}{cfg.subjectName}/ses{cfg.session-2}/recognition/../runRecording.csv")
        actualRuns_prepreDay = list(runRecording_prepreDay['run'].iloc[list(np.where(1==1*(runRecording_prepreDay['type']=='recognition'))[0])])[-(8-len(actualRuns)-len(actualRuns_preDay)):] # might be [5,6,7,8]
    else:
        actualRuns_prepreDay = []

    objects = ['bed', 'bench', 'chair', 'table']

    brain_data=[]
    behav_data=[]
    actualRuns.remove(actualRuns[LeaveOutRun-1])
    print(f"actualRuns={actualRuns} after removal")

    for ii,run in enumerate(actualRuns): # load behavior and brain data for current session
        t = np.load(f"{cfg.recognition_dir}brain_run{run}.npy")
        t = normalize(t)
        brain_data.append(t)

        t = pd.read_csv(f"{cfg.recognition_dir}behav_run{run}.csv")
        t=list(t['Item'])
        behav_data.append(t)
    
    if tmp_folder=='' or tmp_folder=='_':
        tmp_folder = f"tmp__folder_{time.strftime('%Y-%m-%d-%H-%M-%S', time.localtime(time.time()))}_{time.time()}" 
    print(f"tmp_folder={tmp_folder}")
    mkdir(f"{cfg.projectDir}{tmp_folder}")
    save_obj([brain_data,behav_data],f"{cfg.projectDir}{tmp_folder}/{subject}_{dataSource}_{roiloc}_{N}") #{len(topN)}_{i}

    def wait(tmpFile):
        while not os.path.exists(tmpFile+'_result.npy'):
            time.sleep(5)
            print(f"waiting for {tmpFile}_result.npy\n")
        return np.load(tmpFile+'_result.npy',allow_pickle=True)

    def numOfRunningJobs():
        # subprocess.Popen(['squeue -u kp578 | wc -l > squeue.txt'],shell=True) # sl_result = Class(_runs, bcvar)
        randomID=str(time.time())
        # print(f"squeue -u kp578 | wc -l > squeue/{randomID}.txt")
        call(f'squeue -u kp578 | wc -l > {cfg.projectDir}squeue/{randomID}.txt',shell=True)
        numberOfJobsRunning = int(open(f"{cfg.projectDir}squeue/{randomID}.txt", "r").read())
        print(f"numberOfJobsRunning={numberOfJobsRunning}")
        return numberOfJobsRunning

    def Class(brain_data,behav_data):
        # metas = bcvar[0]
        # data4d = data[0]
        print([t.shape for t in brain_data])

        accs = []
        for run in range(len(brain_data)):
            testX = brain_data[run]
            testY = behav_data[run]

            trainX=np.zeros((1,1))
            for i in range(len(brain_data)):
                if i !=run:
                    trainX=brain_data[i] if trainX.shape==(1,1) else np.concatenate((trainX,brain_data[i]),axis=0)

            trainY = []
            for i in range(len(brain_data)):
                if i != run:
                    trainY.extend(behav_data[i])
            clf = LogisticRegression(penalty='l2',C=1, solver='lbfgs', max_iter=1000, 
                                    multi_class='multinomial').fit(trainX, trainY)
                    
            # Monitor progress by printing accuracy (only useful if you're running a test set)
            acc = clf.score(testX, testY)
            accs.append(acc)
        
        return np.mean(accs)

    if not os.path.exists(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}.pkl"):
        brain_data = [t[:,mask==1] for t in brain_data]
        # _runs = [runs[:,mask==1]]
        print("Runs shape", [t.shape for t in brain_data])
        slstart = time.time()
        sl_result = Class(brain_data, behav_data)
        print(f"passed {time.time()-slstart}s for training")
        save_obj({"subject":subject,
        "startFromN":N,
        "currNumberOfROI":len(topN),
        "bestAcc":sl_result, # this is the sl_result for the topN, not the bestAcc, bestAcc is for the purpose of keeping consistent with others
        "bestROIs":topN},# this is the topN, not the bestROIs, bestROIs is for the purpose of keeping consistent with others
        f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}"
        )

    if os.path.exists(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{1}.pkl"):
        print(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_1.pkl exists")


        # when every mask has run, find the best mask and save as the chosenMask
        roiloc="schaefer2018"
        dataSource="realtime"
        subjects=[cfg.subjectName]
        N=N
        GreedyBestAcc=np.zeros((len(subjects),N+1))
        GreedyBestAcc[GreedyBestAcc==0]=None
        for ii,subject in enumerate(subjects):
            for len_topN_1 in range(N-1,0,-1):
                try:
                    # print(f"./{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                    di = load_obj(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                    GreedyBestAcc[ii,len_topN_1-1] = di['bestAcc']
                except:
                    pass
        GreedyBestAcc=GreedyBestAcc.T

        # import matplotlib.pyplot as plt
        # plt.imshow(GreedyBestAcc)
        # _=plt.figure()
        # for i in range(GreedyBestAcc.shape[0]):
        #     plt.scatter([i]*GreedyBestAcc.shape[1],GreedyBestAcc[i],c='g',s=2)
        # plt.plot(np.arange(GreedyBestAcc.shape[0]),np.nanmean(GreedyBestAcc,axis=1))

        performance_mean = np.nanmean(GreedyBestAcc,axis=1)
        bestID=np.where(performance_mean==max(performance_mean))[0][0]
        di = load_obj(f"{cfg.projectDir}/{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{bestID+1}")
        print(f"bestID={bestID}; best Acc = {di['bestAcc']}")
        print(f"bestROIs={di['bestROIs']}")
        
        append_file(recordingTxt,f"bestID={bestID}; best Acc = {di['bestAcc']}")
        append_file(recordingTxt,f"bestROIs={di['bestROIs']}")

        mask = getMask(di['bestROIs'],cfg)
        np.save(f"{cfg.recognition_dir}chosenMask_leave_{LeaveOutRun}_out.npy",mask)
        
        
        return recordingTxt
        # raise Exception('runned or running')

    # N-1
    def next(topN):
        print(f"len(topN)={len(topN)}")
        print(f"topN={topN}")
        print(f"kp 6")
        if len(topN)==1:
            return None
        else:
            print(f"kp 7")
            allpairs = itertools.combinations(topN,len(topN)-1)
            topNs=[]
            sl_results=[]
            tmpFiles=[]
            while os.path.exists(f"{cfg.projectDir}{tmp_folder}/holdon.npy"):
                time.sleep(10)
                print(f"sleep for 10s ; waiting for {cfg.projectDir}{tmp_folder}/holdon.npy to be deleted")
            np.save(f"{cfg.projectDir}{tmp_folder}/holdon",1)
            print(f"kp 8")
            # 对于每一个round，提交一个job array，然后等待这个job array完成之后再进行下一轮
            # 具体的方法是首先保存需要的input，也就是这一轮需要用到的tmpFile，然后再将tmpFile除了之外的字符串输入
            skip_flag=0
            for i,_topN in enumerate(allpairs):
                tmpFile=f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}_{i}"
                print(f"tmpFile={tmpFile}")
                topNs.append(_topN)
                tmpFiles.append(tmpFile)
                print(f"kp 9")
                if not os.path.exists(tmpFile+'_result.npy'):
                    # prepare brain data(runs) mask and behavior data(bcvar) 
                    save_obj([_topN,subject,dataSource,roiloc,N], tmpFile)
                    print(f"kp 10")
                else:
                    print(tmpFile+'_result.npy exists!')
                    skip_flag+=1
                    print(f"kp 11")

            if skip_flag!=(i+1): # 如果有一个不存在，就需要跑一跑
                command=f'sbatch --array=1-{i+1} {cfg.recognition_expScripts_dir}class_LOO.sh {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}_'
                print(command)
                proc = subprocess.Popen([command], shell=True) # sl_result = Class(_runs, bcvar) 
            else:
                command=f'sbatch --array=1-{i+1} {cfg.recognition_expScripts_dir}class_LOO.sh {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)}_'
                print(f"skip {command}")
                print(f"kp 1")
            try:
                os.remove(f"{cfg.projectDir}{tmp_folder}/holdon.npy")
                print(f"kp 2")
            except:
                pass
            print(f"kp 3")
            # wait for everything to be finished and make a summary to find the best performed megaROI
            sl_results=[]
            for tmpFile in tmpFiles:
                print(f"kp 3.1")
                print(f"tmpFile={tmpFile}")
                sl_result=wait(tmpFile)
                print(f"kp 3.2")
                sl_results.append(sl_result)
                print(f"kp 3.3")
            print(f"kp 4")
            print(f"sl_results={sl_results}")
            print(f"max(sl_results)=={max(sl_results)}")
            maxID=np.where(sl_results==max(sl_results))[0][0]
            save_obj({"subject":subject,
            "startFromN":N,
            "currNumberOfROI":len(topN)-1,
            "bestAcc":max(sl_results),
            "bestROIs":topNs[maxID]},
            f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}"
            )
            print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
            print(f"kp 5")
            tmpFiles=next(topNs[maxID])
            return 0
    tmpFiles=next(topN)



    # when every mask has run, find the best mask and save as the chosenMask
    roiloc="schaefer2018"
    dataSource="realtime"
    subjects=[cfg.subjectName]
    N=N
    GreedyBestAcc=np.zeros((len(subjects),N+1))
    GreedyBestAcc[GreedyBestAcc==0]=None
    for ii,subject in enumerate(subjects):
        for len_topN_1 in range(N-1,0,-1):
            try:
                # print(f"./{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                di = load_obj(f"{cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len_topN_1}")
                GreedyBestAcc[ii,len_topN_1-1] = di['bestAcc']
            except:
                pass
    GreedyBestAcc=GreedyBestAcc.T

    # import matplotlib.pyplot as plt
    # plt.imshow(GreedyBestAcc)
    # _=plt.figure()
    # for i in range(GreedyBestAcc.shape[0]):
    #     plt.scatter([i]*GreedyBestAcc.shape[1],GreedyBestAcc[i],c='g',s=2)
    # plt.plot(np.arange(GreedyBestAcc.shape[0]),np.nanmean(GreedyBestAcc,axis=1))

    performance_mean = np.nanmean(GreedyBestAcc,axis=1)
    bestID=np.where(performance_mean==max(performance_mean))[0][0]
    di = load_obj(f"{cfg.projectDir}/{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{bestID+1}")
    print(f"bestID={bestID}; best Acc = {di['bestAcc']}")
    print(f"bestROIs={di['bestROIs']}")
    
    append_file(recordingTxt,f"bestID={bestID}; best Acc = {di['bestAcc']}")
    append_file(recordingTxt,f"bestROIs={di['bestROIs']}")

    mask = getMask(di['bestROIs'],cfg)
    np.save(f"{cfg.recognition_dir}chosenMask_leave_{LeaveOutRun}_out.npy",mask)
    
    
    
    return recordingTxt


def wait(waitfor, delay=0.01):
    while not os.path.exists(waitfor):
        print("kp 12")
        print('waiting for {}'.format(waitfor))
        time.sleep(delay)
    print(f"found {waitfor}")

# %%
recordingTxt=greedyMask(cfg, LeaveOutRun=int(LeaveOutRun),recordingTxt=recordingTxt,tmp_folder=tmp_folder)
# Out:
# Running subject sub005, with realtime as a data source, schaefer2018, starting with 78 ROIs
# len(topN)=78
# GMschaefer_ topN loaded from neurosketch=['234.nii.gz', '19.nii.gz', '225.nii.gz', '8.nii.gz', '86.nii.gz', '223.nii.gz', '159.nii.gz', '240.nii.gz', '148.nii.gz', '120.nii.gz', '195.nii.gz', '114.nii.gz', '222.nii.gz', '179.nii.gz', '65.nii.gz', '272.nii.gz', '235.nii.gz', '163.nii.gz', '56.nii.gz', '77.nii.gz', '108.nii.gz', '76.nii.gz', '284.nii.gz', '139.nii.gz', '295.nii.gz', '166.nii.gz', '271.nii.gz', '40.nii.gz', '164.nii.gz', '258.nii.gz', '151.nii.gz', '80.nii.gz', '89.nii.gz', '41.nii.gz', '214.nii.gz', '132.nii.gz', '249.nii.gz', '49.nii.gz', '259.nii.gz', '112.nii.gz', '21.nii.gz', '126.nii.gz', '58.nii.gz', '237.nii.gz', '218.nii.gz', '190.nii.gz', '186.nii.gz', '93.nii.gz', '67.nii.gz', '10.nii.gz', '209.nii.gz', '211.nii.gz', '230.nii.gz', '265.nii.gz', '52.nii.gz', '146.nii.gz', '205.nii.gz', '2.nii.gz', '238.nii.gz', '133.nii.gz', '220.nii.gz', '263.nii.gz', '204.nii.gz', '150.nii.gz', '39.nii.gz', '62.nii.gz', '281.nii.gz', '160.nii.gz', '246.nii.gz', '243.nii.gz', '280.nii.gz', '87.nii.gz', '22.nii.gz', '193.nii.gz', '244.nii.gz', '53.nii.gz', '30.nii.gz', '79.nii.gz']
# /gpfs/milgram/project/turk-browne/users/kp578/CONDA/rtcloud/lib/python3.6/site-packages/ipykernel_launcher.py:62: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# mask dimensions: (64, 64, 36)
# number of voxels in mask: 4887
# actualRuns=[1, 2, 3, 5, 6, 7, 8] after removal
# /gpfs/milgram/project/turk-browne/users/kp578/CONDA/rtcloud/lib/python3.6/site-packages/scipy/stats/stats.py:2500: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# tmp_folder=tmp__folder_2021-06-30-02-29-57_1625034597.718328/
# len(topN)=78
# topN=['234.nii.gz', '19.nii.gz', '225.nii.gz', '8.nii.gz', '86.nii.gz', '223.nii.gz', '159.nii.gz', '240.nii.gz', '148.nii.gz', '120.nii.gz', '195.nii.gz', '114.nii.gz', '222.nii.gz', '179.nii.gz', '65.nii.gz', '272.nii.gz', '235.nii.gz', '163.nii.gz', '56.nii.gz', '77.nii.gz', '108.nii.gz', '76.nii.gz', '284.nii.gz', '139.nii.gz', '295.nii.gz', '166.nii.gz', '271.nii.gz', '40.nii.gz', '164.nii.gz', '258.nii.gz', '151.nii.gz', '80.nii.gz', '89.nii.gz', '41.nii.gz', '214.nii.gz', '132.nii.gz', '249.nii.gz', '49.nii.gz', '259.nii.gz', '112.nii.gz', '21.nii.gz', '126.nii.gz', '58.nii.gz', '237.nii.gz', '218.nii.gz', '190.nii.gz', '186.nii.gz', '93.nii.gz', '67.nii.gz', '10.nii.gz', '209.nii.gz', '211.nii.gz', '230.nii.gz', '265.nii.gz', '52.nii.gz', '146.nii.gz', '205.nii.gz', '2.nii.gz', '238.nii.gz', '133.nii.gz', '220.nii.gz', '263.nii.gz', '204.nii.gz', '150.nii.gz', '39.nii.gz', '62.nii.gz', '281.nii.gz', '160.nii.gz', '246.nii.gz', '243.nii.gz', '280.nii.gz', '87.nii.gz', '22.nii.gz', '193.nii.gz', '244.nii.gz', '53.nii.gz', '30.nii.gz', '79.nii.gz']
# kp 6
# kp 7
# kp 8
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_0
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_0_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_1
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_1_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_2
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_2_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_3
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_3_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_4
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_4_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_5
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_5_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_6
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_6_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_7
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_7_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_8
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_8_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_9
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_9_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_10
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_10_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_11
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_11_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_12
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_12_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_13
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_13_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_14
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_14_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_15
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_15_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_16
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_16_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_17
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_17_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_18
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_18_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_19
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_19_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_20
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_20_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_21
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_21_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_22
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_22_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_23
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_23_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_24
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_24_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_25
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_25_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_26
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_26_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_27
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_27_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_28
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_28_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_29
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_29_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_30
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_30_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_31
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_31_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_32
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_32_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_33
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_33_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_34
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_34_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_35
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_35_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_36
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_36_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_37
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_37_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_38
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_38_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_39
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_39_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_40
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_40_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_41
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_41_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_42
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_42_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_43
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_43_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_44
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_44_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_45
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_45_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_46
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_46_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_47
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_47_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_48
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_48_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_49
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_49_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_50
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_50_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_51
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_51_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_52
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_52_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_53
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_53_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_54
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_54_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_55
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_55_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_56
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_56_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_57
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_57_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_58
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_58_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_59
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_59_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_60
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_60_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_61
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_61_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_62
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_62_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_63
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_63_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_64
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_64_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_65
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_65_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_66
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_66_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_67
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_67_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_68
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_68_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_69
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_69_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_70
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_70_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_71
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_71_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_72
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_72_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_73
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_73_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_74
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_74_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_75
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_75_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_76
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_76_result.npy exists!
# kp 11
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_77
# kp 9
# /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_77_result.npy exists!
# kp 11
# skip sbatch --array=1-78 /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/expScripts/recognition/class_LOO.sh /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_
# kp 1
# kp 2
# kp 3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_0
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_1
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_2
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_3
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_4
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_5
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_6
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_7
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_8
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_9
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_10
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_11
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_12
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_13
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_14
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_15
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_16
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_17
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_18
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_19
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_20
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_21
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_22
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_23
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_24
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_25
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_26
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_27
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_28
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_29
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_30
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_31
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_32
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_33
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_34
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_35
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_36
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_37
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_38
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_39
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_40
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_41
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_42
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_43
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_44
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_45
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_46
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_47
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_48
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_49
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_50
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_51
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_52
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_53
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_54
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_55
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_56
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_57
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_58
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_59
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_60
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_61
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_62
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_63
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_64
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_65
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_66
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_67
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_68
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_69
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_70
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_71
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_72
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_73
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_74
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_75
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_76
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_78_77
# kp 3.2
# kp 3.3
# kp 4
# sl_results=[array(0.33658484), array(0.35476411), array(0.33956379), array(0.35153187), array(0.35489351), array(0.3427327), array(0.33988866), array(0.35133915), array(0.34538401), array(0.3576109), array(0.32714143), array(0.35146579), array(0.34855568), array(0.3638854), array(0.35761365), array(0.36090921), array(0.36686159), array(0.35159795), array(0.35172459), array(0.36983778), array(0.35495958), array(0.35159519), array(0.35172459), array(0.33943163), array(0.36071649), array(0.36408088), array(0.34855568), array(0.35159519), array(0.33354533), array(0.35483018), array(0.35780637), array(0.3579991), array(0.34855568), array(0.34551341), array(0.3577403), array(0.36375876), array(0.3577403), array(0.34842628), array(0.33943439), array(0.3728773), array(0.3577403), array(0.34577221), array(0.36084864), array(0.33968768), array(0.35780637), array(0.35172459), array(0.34564281), array(0.34855293), array(0.34260055), array(0.35185399), array(0.3483602), array(0.33956103), array(0.35444198), array(0.35172735), array(0.34577221), array(0.35780637), array(0.34577221), array(0.34596494), array(0.36375876), array(0.33335261), array(0.32429188), array(0.35457138), array(0.3578697), array(0.3577403), array(0.35165852), array(0.35470078), array(0.34875116), array(0.34266662), array(0.3365876), array(0.35767697), array(0.34577221), array(0.34564557), array(0.34266662), array(0.35496234), array(0.3490072), array(0.35450806), array(0.34881173), array(0.35172459)]
# max(sl_results)==0.3728772961543544
# bestAcc=0.3728772961543544 For 77 = /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_77
# kp 5
# ...
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_11
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_12
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_13
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_14
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_15
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_16
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_17
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_18
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_19
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_20
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_21
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_22
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_23
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_24
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_25
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_26
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_27
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_28
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_29
# kp 3.2
# kp 3.3
# kp 3.1
# tmpFile=/gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_30
# waiting for /gpfs/milgram/project/turk-browne/projects/rt-cloud/projects/rtSynth_rt/tmp__folder_2021-06-30-02-29-57_1625034597.718328//sub005_78_schaefer2018_realtime_47_30_result.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-d60a04171457> in <module>
# ----> 1 recordingTxt=greedyMask(cfg, LeaveOutRun=int(LeaveOutRun),recordingTxt=recordingTxt,tmp_folder=tmp_folder)
#
# <ipython-input-24-f6e3c2b2889d> in greedyMask(cfg, N, LeaveOutRun, recordingTxt, tmp_folder)
#     286             tmpFiles=next(topNs[maxID])
#     287             return 0
# --> 288     tmpFiles=next(topN)
#     289
#     290
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     284             print(f"bestAcc={max(sl_results)} For {len(topN)-1} = {cfg.projectDir}{tmp_folder}/{subject}_{N}_{roiloc}_{dataSource}_{len(topN)-1}")
#     285             print(f"kp 5")
# --> 286             tmpFiles=next(topNs[maxID])
#     287             return 0
#     288     tmpFiles=next(topN)
#
# <ipython-input-24-f6e3c2b2889d> in next(topN)
#     267                 print(f"kp 3.1")
#     268                 print(f"tmpFile={tmpFile}")
# --> 269                 sl_result=wait(tmpFile)
#     270                 print(f"kp 3.2")
#     271                 sl_results.append(sl_result)
#
# <ipython-input-24-f6e3c2b2889d> in wait(tmpFile)
#     112     def wait(tmpFile):
#     113         while not os.path.exists(tmpFile+'_result.npy'):
# --> 114             time.sleep(5)
#     115             print(f"waiting for {tmpFile}_result.npy\n")
#     116         return np.load(tmpFile+'_result.npy',allow_pickle=True)
#
# KeyboardInterrupt:

# %%
# Out:
# 'tmp__folder_2021-06-30-02-29-57_1625034597.718328/'
